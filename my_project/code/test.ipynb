# %%
import torch

print(torch.__file__)
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# d:\IC_2025\IRP\workspace\venv\Lib\site-packages\torch\__init__.py
# 2.7.1+cu118
# 11.8
# True
